# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_csv('adult.csv')
import numpy as np

# %%
data
# Out:
#       age  workclass  fnlwgt     education  educational-num  \
# 0      25    Private  226802          11th                7
# 1      38    Private   89814       HS-grad                9
# 2      28  Local-gov  336951    Assoc-acdm               12
# 3      44    Private  160323  Some-college               10
# 4      18          ?  103497  Some-college               10
# ...   ...        ...     ...           ...              ...
# 9610   25    Private  318644     Bachelors               13
# 9611   20    Private  227594       HS-grad                9
# 9612   59    Private  165695    Assoc-acdm               12
# 9613   55    Private  127728       HS-grad                9
# 9614   49    Private  123681    Assoc-acdm               12
#
#           marital-status         occupation relationship   race  gender  \
# 0          Never-married  Machine-op-inspct    Own-child  Black    Male
# 1     Married-civ-spouse    Farming-fishing      Husband  White    Male
# ...

# %%
#top Row of data
data.head (10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
# Last row of dataset
data.tail(10)
# Out:
#       age  workclass  fnlwgt     education  educational-num  \
# 9605   33  State-gov   30494       HS-grad                9
# 9606   29    Private  256764     Bachelors               13
# 9607   20          ?   49819  Some-college               10
# 9608   42          ?  338281     Assoc-voc               11
# 9609   21  Local-gov  256356  Some-college               10
# 9610   25    Private  318644     Bachelors               13
# 9611   20    Private  227594       HS-grad                9
# 9612   59    Private  165695    Assoc-acdm               12
# 9613   55    Private  127728       HS-grad                9
# 9614   49    Private  123681    Assoc-acdm               12
#
#           marital-status        occupation   relationship   race  gender  \
# 9605            Divorced    Prof-specialty      Unmarried  White  Female
# 9606       Never-married             Sales  Not-in-family  White    Male
# 9607       Never-married                 ?      Own-child  White  Female
# ...

# %%
#Shape of dataset (number of rows and column )
data.shape 
#its not shape its attribute
# Out:
# (9615, 15)

# %%
print ("number of Row",data.shape[0])
print ("number of Column",data.shape[1])
# Out:
# number of Row 9615
# number of Column 15

# %%
#information about number of row and column eanc column and its requirment
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9615 entries, 0 to 9614
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              9615 non-null   int64
#  1   workclass        9615 non-null   object
#  2   fnlwgt           9615 non-null   int64
#  3   education        9615 non-null   object
#  4   educational-num  9615 non-null   int64
#  5   marital-status   9615 non-null   object
#  6   occupation       9615 non-null   object
#  7   relationship     9615 non-null   object
#  8   race             9614 non-null   object
#  9   gender           9614 non-null   object
#  10  capital-gain     9614 non-null   float64
#  11  capital-loss     9614 non-null   float64
#  12  hours-per-week   9614 non-null   float64
#  13  native-country   9614 non-null   object
#  14  income           9614 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 1.1+ MB

# %%
#fatch random sample of dataset(50%)  (each time different sample)
data.sample(frac=0.50)
# Out:
#       age workclass  fnlwgt   education  educational-num      marital-status  \
# 5516   27   Private   38353     HS-grad                9            Divorced
# 4396   30   Private  348592        10th                6  Married-civ-spouse
# 741    40   Private  168113     HS-grad                9  Married-civ-spouse
# 7606   30   Private  226296     Masters               14  Married-civ-spouse
# 9509   23   Private  142766   Bachelors               13       Never-married
# ...   ...       ...     ...         ...              ...                 ...
# 2896   22   Private  201615  Assoc-acdm               12       Never-married
# 8159   36   Private   68798     HS-grad                9       Never-married
# 8255   25   Private   39212   Bachelors               13  Married-civ-spouse
# 6340   38   Private  268893   Assoc-voc               11  Married-civ-spouse
# 6848   29   Private  174163     Masters               14       Never-married
#
# ...

# %%
##fatch random sample of dataset(50%)  to fix number it will not change  
data1=data.sample(frac=0.50,random_state=100)
data1
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 7750   49           Private   52184       HS-grad                9
# 5477   57           Private  337001       Masters               14
# 3157   22           Private  255575       HS-grad                9
# 686    58  Self-emp-not-inc  237546  Some-college               10
# 5161   38         Local-gov  173804     Bachelors               13
# ...   ...               ...     ...           ...              ...
# 2635   32           Private  108256          12th                8
# 9312   32                 ?  340580       HS-grad                9
# 5380   28           Private  113635          12th                8
# 4144   33           Private  164683       HS-grad                9
# 6250   18                 ?  305327  Some-college               10
#
#           marital-status         occupation   relationship   race  gender  \
# 7750  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# ...

# %%
#Null value in dataset in boloan
data.isnull()
# Out:
#         age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0     False      False   False      False            False           False
# 1     False      False   False      False            False           False
# 2     False      False   False      False            False           False
# 3     False      False   False      False            False           False
# 4     False      False   False      False            False           False
# ...     ...        ...     ...        ...              ...             ...
# 9610  False      False   False      False            False           False
# 9611  False      False   False      False            False           False
# 9612  False      False   False      False            False           False
# 9613  False      False   False      False            False           False
# 9614  False      False   False      False            False           False
#
# ...

# %%
#not missing value
data.isnull().sum(0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               1
# gender             1
# capital-gain       1
# capital-loss       1
# hours-per-week     1
# native-country     1
# income             1
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#replace ? nan  (Data cleaning)

data.tail(20)
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 9595   24           Private  114292  Some-college               10
# 9596   32           Private  227608     Assoc-voc               11
# 9597   21         State-gov  185554  Some-college               10
# 9598   46  Self-emp-not-inc  181372     Bachelors               13
# 9599   19           Private  344592       HS-grad                9
# 9600   29  Self-emp-not-inc  102326     Bachelors               13
# 9601   43  Self-emp-not-inc  220647     Bachelors               13
# 9602   18                 ?   30246          11th                7
# 9603   33           Private  496743       HS-grad                9
# 9604   21           Private  161508       HS-grad                9
# 9605   33         State-gov   30494       HS-grad                9
# 9606   29           Private  256764     Bachelors               13
# 9607   20                 ?   49819  Some-college               10
# ...

# %%
data.isin(['?']).sum()
# Out:
# age                  0
# workclass          584
# fnlwgt               0
# education            0
# educational-num      0
# marital-status       0
# occupation         585
# relationship         0
# race                 0
# gender               0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     164
# income               0
# dtype: int64

# %%
#  using numpy repalce np / (workclass),(occupation,(native..)
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['workclass']=data['workclass'].replace('?',np.nan)
data['occupation']=data['occupation'].replace('?',np.nan)
data['native-country']=data['native-country'].replace('?',np.nan)

# %%
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum(0)
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#Drop all missing values
per_missing=data.isnull().sum()*100/len(data)
per_missing
# Out:
# age                0.000000
# workclass          6.073843
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         6.084243
# relationship       0.000000
# race               0.010400
# gender             0.010400
# capital-gain       0.010400
# capital-loss       0.010400
# hours-per-week     0.010400
# native-country     1.716069
# income             0.010400
# dtype: float64

# %%
data.dropna(how='any',inplace=True)
data.shape
# Out:
# (8877, 15)

# %%
#oraginal rows - resent rows

9615-8877
# this 738 rows are drop from data frame
# Out:
# 738

# %%
#check dupblicate data and drop it 

dup=data.duplicated().any()
print("Are there any dublicate data",dup)
# Out:
# Are there any dublicate data True

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (8876, 15)

# %%
8877-8876
# so duplicate value is 1 which is droped
# Out:
# 1

# %%
# get all statisics about data frame

data.describe ()
# Out:
#                age        fnlwgt  educational-num  capital-gain  capital-loss  \
# count  8876.000000  8.876000e+03      8876.000000   8876.000000   8876.000000
# mean     38.660545  1.883237e+05        10.122465   1170.668770     89.610185
# std      13.366109  1.050655e+05         2.551683   8061.604969    408.590884
# min      17.000000  1.376900e+04         1.000000      0.000000      0.000000
# 25%      28.000000  1.156482e+05         9.000000      0.000000      0.000000
# 50%      37.000000  1.779200e+05        10.000000      0.000000      0.000000
# 75%      48.000000  2.374290e+05        13.000000      0.000000      0.000000
# max      90.000000  1.490400e+06        16.000000  99999.000000   3770.000000
#
#        hours-per-week
# count     8876.000000
# mean        41.090807
# std         12.041407
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
#    Analysis 
#  what is disruption of age columns

data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['age'].describe()
# Out:
# count    8876.000000
# mean       38.660545
# std        13.366109
# min        17.000000
# 25%        28.000000
# 50%        37.000000
# 75%        48.000000
# max        90.000000
# Name: age, dtype: float64

# %%
data['age'].hist()
# Out:
# <Axes: >

# %%
(data['age']>=17) & (data['age']>=48)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 9609    False
# 9610    False
# 9611    False
# 9612     True
# 9613     True
# Name: age, Length: 8876, dtype: bool

# %%
#  other way is 

data['age'].between(17,48)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 5        True
#         ...
# 9609     True
# 9610     True
# 9611     True
# 9612    False
# 9613    False
# Name: age, Length: 8876, dtype: bool
